# %% [markdown]
# ## **Unsupervised Learning**

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %% [markdown]
# Generate some (random) data

# %%
X, Y = datasets.make_blobs(300, 2, centers=4, random_state=6, cluster_std=1.4)

plt.scatter(X[:,0], X[:,1], c=Y, s=50, cmap='RdBu')
plt.show()

# %% [markdown]
# **K-Means Clustering**

# %%
km = KMeans(n_clusters=4)
km.fit(X)
# Out:
# KMeans(n_clusters=4)

# %%
print(km.cluster_centers_)   # cluster centers
# Out:
# [[-7.72186668  1.76037855]
#  [ 8.00415128 -3.41179343]
#  [ 0.52535163 -1.71009254]
#  [ 6.48752474 -8.90904705]]

# %%
print(km.labels_)    # labels
# Out:
# [3 1 1 0 3 0 3 2 0 1 3 3 0 0 2 1 2 0 0 1 2 3 2 2 3 0 0 1 3 3 0 3 0 2 3 3 3
#  2 0 3 1 2 3 0 3 0 0 0 2 3 2 2 2 1 0 1 1 0 0 0 0 3 1 1 0 1 3 2 2 3 1 1 1 1
#  3 2 1 0 0 3 1 2 3 2 2 3 0 1 1 2 3 2 2 0 2 1 2 1 1 0 0 2 3 1 2 3 0 2 0 2 0
#  1 1 3 1 1 3 0 0 0 0 0 2 1 2 2 1 3 1 3 3 3 1 2 2 3 2 1 0 2 1 1 1 3 3 0 3 1
#  3 2 0 3 3 3 1 2 2 3 2 1 2 0 3 2 2 2 1 0 2 3 2 0 3 1 1 2 3 0 1 1 0 1 2 1 3
#  2 3 1 2 0 0 3 2 3 2 0 2 0 0 0 0 2 0 3 1 1 0 0 3 2 2 3 1 3 1 2 2 2 1 3 0 3
#  2 1 0 0 1 0 0 1 3 0 2 3 1 2 3 0 2 0 2 2 0 3 1 3 2 3 2 3 1 2 2 3 2 3 3 0 0
#  0 1 3 1 0 1 0 1 2 0 1 1 3 2 1 2 0 2 1 2 1 3 1 3 1 0 1 3 0 2 2 1 1 1 3 0 3
#  3 3 0 0]

# %%
plt.scatter(X[:,0], X[:,1], c=km.labels_, s=50, cmap='viridis')
centers = km.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)
plt.show()

# %%
km2 = KMeans(n_clusters=2)
km2.fit(X)

plt.scatter(X[:,0], X[:,1], c=km2.labels_, s=50, cmap='viridis')
centers = km2.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.5)
plt.show()

# %% [markdown]
# **Hierarchical Clustering**

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
X, Y = datasets.make_blobs(6, 2, centers=4, random_state=11, cluster_std=1.4)
print(X)
# Out:
# [[ -1.97636501   3.83265169]
#  [ -5.80513522 -11.10233934]
#  [  0.22992576   5.28434763]
#  [ -3.42369582  -1.8587234 ]
#  [ -8.71281136   1.95191985]
#  [ -7.14588733  -9.16893143]]

# %%
fig, ax = plt.subplots()
ax.scatter(X[:,0], X[:,1])
for i, txt in enumerate(range(0, 6)):
  ax.annotate(txt, (X[i,0], X[i,1]), fontsize=15)

# %%
linked = linkage(X, 'single')

# %%
print(linked)
# Out:
# [[1.         5.         2.35280309 2.        ]
#  [0.         2.         2.64104905 2.        ]
#  [3.         7.         5.8725222  3.        ]
#  [4.         8.         6.51887607 4.        ]
#  [6.         9.         8.20328295 6.        ]]

# %%
dendrogram(linked, orientation='top', distance_sort='descending', show_leaf_counts=True)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [10.0, 10.0, 25.0, 25.0],
#   [17.5, 17.5, 35.0, 35.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [26.25, 26.25, 50.0, 50.0]],
#  'dcoord': [[0.0, 2.641049045885157, 2.641049045885157, 0.0],
#   [2.641049045885157, 5.872522199146661, 5.872522199146661, 0.0],
#   [5.872522199146661, 6.518876066552661, 6.518876066552661, 0.0],
#   [0.0, 2.3528030857941205, 2.3528030857941205, 0.0],
#   [6.518876066552661,
#    8.203282945531985,
#    8.203282945531985,
#    2.3528030857941205]],
#  'ivl': ['2', '0', '3', '4', '5', '1'],
#  'leaves': [2, 0, 3, 4, 5, 1],
#  'color_list': ['C1', 'C0', 'C0', 'C2', 'C0'],
#  'leaves_color_list': ['C1', 'C1', 'C0', 'C0', 'C2', 'C2']}

# %%
hm = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='single')
hm.fit(X)
# Out:
# AgglomerativeClustering(linkage='single')

# %%
print(hm.labels_)
# Out:
# [0 1 0 0 0 1]

# %%
plt.scatter(X[:,0], X[:,1], c=hm.labels_, s=50, cmap='viridis')
plt.show()

# %% [markdown]
# **Image Clustering**

# %%
from skimage import data
from skimage.transform import resize
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

# %%
coffee = data.coffee()
coffee = resize(coffee, (100, 150))
plt.imshow(coffee)

# %%
print(coffee.shape)
# Out:
# (100, 150, 3)

# %%
coffee = coffee.reshape(100*150,3)
print(coffee.shape)
# Out:
# (15000, 3)

# %%
km = KMeans(n_clusters=5)
km.fit(coffee)
# Out:
# KMeans(n_clusters=5)

# %%
coffee_km = km.labels_.reshape(100, 150)
plt.imshow(coffee_km)

# %%
hm = AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='complete')
hm.fit(coffee)
# Out:
# AgglomerativeClustering(linkage='complete', n_clusters=5)

# %%
coffee_hm = hm.labels_.reshape(100, 150)
plt.imshow(coffee_hm)
